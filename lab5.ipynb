# %% [markdown]
# # Logistic Regression Classification

# %%
import tensorflow as tf

x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
# classification에서는 y데이터가 0 또는 1로 주어진다
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

# placeholder for a tensor that will be always fed
X = tf.placeholder(tf.float32, shape=[None,2])
Y = tf.placeholder(tf.float32, shape=[None,1])

# W의 shape은 XW = Y => [None,1][?,?] = [None,1]
W = tf.Variable(tf.random_normal([2,1]), name ='weight')
b = tf.Variable(tf.random_normal([1]), name = "bias")

# Hypothesis using sigmoid
hypothesis = tf.sigmoid(tf.matmul(X,W) + b)

# cost/loss function
cost = -tf.reduce_mean(Y*tf.log(hypothesis) + (1 - Y)*tf.log(1 - hypothesis))

# minimize cost
train = tf.train.GradientDescentOptimizer(learning_rate = 0.01).minimize(cost)

# True if hypothesis >= 0.5 else False
# cast True -> 1 False -> 0
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
# 실제 데이터 값과 hypothesis가 얼마나 유사한가
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Lauch graph
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        cost_val, _ = sess.run([cost, train], feed_dict={X: x_data, Y: y_data})
        if step % 200 == 0:
            print(step, cost_val)
    # Accuracy report
    h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data})
    print("\nHypothesis: ", h, "\nCorrect (Y): ", c, "\nAccuracy: ", a)
# Out:
# 0 1.4647269
# 200 0.60061836
# 400 0.50965285
# 600 0.46503803
# 800 0.437627
# 1000 0.41757464
# 1200 0.40114966
# 1400 0.38677207
# 1600 0.37371007
# 1800 0.3615973
# 2000 0.35023654
# 2200 0.3395132
# 2400 0.3293546
# 2600 0.3197098
# 2800 0.31054023
# 3000 0.3018142
# 3200 0.2935038
# 3400 0.28558457
# 3600 0.27803376
# 3800 0.27083012
# 4000 0.26395383
# 4200 0.2573863
# 4400 0.25111014
# 4600 0.24510886
# 4800 0.23936695
# 5000 0.23386991
# 5200 0.22860412
# 5400 0.2235568
# 5600 0.21871598
# 5800 0.21407025
# 6000 0.2096092
# 6200 0.20532297
# 6400 0.20120214
# 6600 0.1972381
# 6800 0.19342263
# 7000 0.1897481
# 7200 0.18620728
# 7400 0.18279342
# 7600 0.17950027
# 7800 0.1763217
# 8000 0.17325239
# 8200 0.17028682
# 8400 0.16742016
# 8600 0.16464774
# 8800 0.16196512
# 9000 0.15936822
# 9200 0.15685317
# 9400 0.15441619
# 9600 0.15205383
# 9800 0.14976291
# 10000 0.14754021
#
# Hypothesis:  [[0.02992209]
#  [0.15772331]
#  [0.30092752]
#  [0.7831874 ]
#  [0.940707  ]
#  [0.9805494 ]]
# Correct (Y):  [[0.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]]
# Accuracy:  1.0
